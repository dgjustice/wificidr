# %% [markdown]
# # Week 3 Forum presentation
#
# ## Markdown and maths (with LaTex)!
#
# $$n = \hat{p}\hat{q}\bigg(\frac{z_{\alpha / 2}}{E}\bigg)^2$$
#
# ```python
# import this
#
# for i in range(42):
#     # Count like The Count
#     print(f"{i} ah-ah-ah!")
# ```
#
# ```shell
# ls ~
# cat /tmp/foo
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from IPython.display import display

df = pd.read_csv("pcap.csv")
df
# Out:
#     No.      Time             Source    Destination Protocol  Length  \
# 0     1  0.000000      18.211.118.21  192.168.1.248      TCP      66
# 1     2  0.000465      18.211.118.21  192.168.1.248  TLSv1.2     122
# 2     3  0.433247    149.112.112.112  192.168.1.248      TCP      66
# 3     4  0.579567    149.112.112.112  192.168.1.248  TLSv1.2     313
# 4     5  1.048138       208.85.40.20  192.168.1.248      TCP      66
# 5     6  1.048299       208.85.40.20  192.168.1.248  TLSv1.2     134
# 6     7  1.108135      192.168.1.229  192.168.1.248      TCP     183
# 7     8  1.454996      50.18.200.106  192.168.1.248      TCP      66
# 8     9  1.456508      50.18.200.106  192.168.1.248      TCP      66
# 9    10  1.719121     149.56.134.238  192.168.1.248  TLSv1.2     134
# 10   11  1.947917      18.215.66.244  192.168.1.248  TLSv1.2     122
# 11   12  3.046015       34.194.201.2  192.168.1.248  TLSv1.2     820
# 12   13  3.454793     54.215.176.103  192.168.1.248      TCP      66
# ...

# %%
df[df.Protocol == "TLSv1.2"]
# Out:
#     No.      Time           Source    Destination Protocol  Length  \
# 1     2  0.000465    18.211.118.21  192.168.1.248  TLSv1.2     122
# 3     4  0.579567  149.112.112.112  192.168.1.248  TLSv1.2     313
# 5     6  1.048299     208.85.40.20  192.168.1.248  TLSv1.2     134
# 9    10  1.719121   149.56.134.238  192.168.1.248  TLSv1.2     134
# 10   11  1.947917    18.215.66.244  192.168.1.248  TLSv1.2     122
# 11   12  3.046015     34.194.201.2  192.168.1.248  TLSv1.2     820
# 17   18  4.495554    18.215.66.244  192.168.1.248  TLSv1.2     816
# 21   22  4.982532    172.217.6.174  192.168.1.248  TLSv1.2     105
# 22   23  5.102002    172.217.6.174  192.168.1.248  TLSv1.2     274
# 23   24  5.102044    172.217.6.174  192.168.1.248  TLSv1.2     320
# 24   25  5.102331    172.217.6.174  192.168.1.248  TLSv1.2      97
# 25   26  5.102526    172.217.6.174  192.168.1.248  TLSv1.2     105
# 28   29  6.052658  149.112.112.112  192.168.1.248  TLSv1.2     105
#
#                 Info
# ...

# %%
df.Length.sum() == df["Length"].sum()
# Out:
# True

# %%
df.Length.hist()

# %%
df.Protocol.hist()

# %%
df.plot.scatter(x="Time", y="Length")

# %%
df[df.Source == "172.217.6.174"].plot.scatter(x="Time", y="Length")

# %% [markdown]
# ## Resources
#
# - https://www.anaconda.com/distribution/
# - https://www.python.org/
# - https://pandas.pydata.org/pandas-docs/stable/index.html
