# %%
# %matplotlib
# %run project1_part1.py
# Out:
# Using matplotlib backend: Qt5Agg
# +---------+---------+-----+---------+------------+-------------+
# |   x_n   |   y_n   |  n  |  Actual | Abs. error | %Rel. error |
# +---------+---------+-----+---------+------------+-------------+
# |  0.0000 | -0.5000 |  0  | -0.5000 |   0.0000   |    0.0000   |
# |  0.0625 | -0.5000 |  1  | -0.4971 |   0.0029   |    0.5886   |
# |  0.1250 | -0.4941 |  2  | -0.4883 |   0.0058   |    1.1882   |
# |  0.1875 | -0.4825 |  3  | -0.4739 |   0.0086   |    1.8067   |
# |  0.2500 | -0.4652 |  4  | -0.4541 |   0.0111   |    2.4542   |
# |  0.3125 | -0.4426 |  5  | -0.4291 |   0.0135   |    3.1441   |
# |  0.3750 | -0.4149 |  6  | -0.3993 |   0.0156   |    3.8953   |
# |  0.4375 | -0.3825 |  7  | -0.3652 |   0.0173   |    4.7365   |
# |  0.5000 | -0.3459 |  8  | -0.3272 |   0.0187   |    5.7127   |
# |  0.5625 | -0.3055 |  9  | -0.2858 |   0.0197   |    6.8998   |
# |  0.6250 | -0.2620 |  10 | -0.2416 |   0.0204   |    8.4351   |
# ...
